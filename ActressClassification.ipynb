# %% [markdown]
# <a href="https://colab.research.google.com/github/htsull/Actress_DL_Classification/blob/main/ActressClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls Actress_DL_Classification/data
# Out:
# train  val

# %%
import torch
import torchvision
from torchvision import transforms
from torchvision.datasets import ImageFolder


#train and test data directory
data_dir = "Actress_DL_Classification/data/train"
test_data_dir = "Actress_DL_Classification/data/val"


#load the train and test data
dataset = ImageFolder(data_dir,transform = transforms.Compose([
    transforms.Resize((150,150)),transforms.ToTensor()
]))
test_dataset = ImageFolder(test_data_dir,transforms.Compose([
    transforms.Resize((150,150)),transforms.ToTensor()
]))

# %%
print("Following classes are there : \n",dataset.classes)
# Out:
# Following classes are there :
#  ['keira', 'nathalie', 'others']

# %%
import matplotlib.pyplot as plt
def display_img(img,label):
    print(f"Label : {dataset.classes[label]}")
    plt.imshow(img.permute(1,2,0))

#display the first image in the dataset
display_img(*dataset[0])
# Out:
# Label : keira
